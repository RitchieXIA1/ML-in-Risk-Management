# %% [markdown]
# I've always wanted to try autoencoders for tabular data and finally found an excuse to try them out. This kernel heavily borrows from https://www.kaggle.com/abazdyrev/keras-nn-focal-loss-experiments who did a better job formatting the data than I did in my first NN starter kernel. https://www.kaggle.com/ryches/keras-nn-starter-w-time-series-split. It takes inspiration from Christof's post here https://www.kaggle.com/c/petfinder-adoption-prediction/discussion/88740#latest-515210 and Michael Jahrer's famous Porto Seguro solution

# %%
import numpy as np
import pandas as pd

train = pd.read_csv('../input/train_transaction.csv')
test = pd.read_csv('../input/test_transaction.csv')
sub = pd.read_csv('../input/sample_submission.csv')

# %%
useful_features = list(train.iloc[:, 3:55].columns)

y = train.sort_values('TransactionDT')['isFraud']
X = train.sort_values('TransactionDT')[useful_features]
X_test = test[useful_features]
del train, test

# %%
categorical_features = [
    'ProductCD',
    'card1', 'card2', 'card3', 'card4', 'card5', 'card6',
    'addr1', 'addr2',
    'P_emaildomain',
    'R_emaildomain',
    'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9'
]

continuous_features = list(filter(lambda x: x not in categorical_features, X))

# %%
class ContinuousFeatureConverter:
    def __init__(self, name, feature, log_transform):
        self.name = name
        self.skew = feature.skew()
        self.log_transform = log_transform
        
    def transform(self, feature):
        if self.skew > 1:
            feature = self.log_transform(feature)
        
        mean = feature.mean()
        std = feature.std()
        return (feature - mean)/(std + 1e-6)

# %%
from tqdm.autonotebook import tqdm

feature_converters = {}
continuous_features_processed = []
continuous_features_processed_test = []

for f in tqdm(continuous_features):
    feature = X[f]
    feature_test = X_test[f]
    log = lambda x: np.log10(x + 1 - min(0, x.min()))
    converter = ContinuousFeatureConverter(f, feature, log)
    feature_converters[f] = converter
    continuous_features_processed.append(converter.transform(feature))
    continuous_features_processed_test.append(converter.transform(feature_test))
    
continuous_train = pd.DataFrame({s.name: s for s in continuous_features_processed}).astype(np.float32)
continuous_test = pd.DataFrame({s.name: s for s in continuous_features_processed_test}).astype(np.float32)
# Out:
# /opt/conda/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)
# HBox(children=(IntProgress(value=0, max=32), HTML(value='')))

# %%
continuous_train['isna_sum'] = continuous_train.isna().sum(axis=1)
continuous_test['isna_sum'] = continuous_test.isna().sum(axis=1)

continuous_train['isna_sum'] = (continuous_train['isna_sum'] - continuous_train['isna_sum'].mean())/continuous_train['isna_sum'].std()
continuous_test['isna_sum'] = (continuous_test['isna_sum'] - continuous_test['isna_sum'].mean())/continuous_test['isna_sum'].std()

# %%
isna_columns = []
for column in tqdm(continuous_features):
    isna = continuous_train[column].isna()
    if isna.mean() > 0.:
        continuous_train[column + '_isna'] = isna.astype(int)
        continuous_test[column + '_isna'] = continuous_test[column].isna().astype(int)
        isna_columns.append(column)
        
continuous_train = continuous_train.fillna(0.)
continuous_test = continuous_test.fillna(0.)
# Out:
# HBox(children=(IntProgress(value=0, max=32), HTML(value='')))

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from tqdm.autonotebook import tqdm

def categorical_encode(df_train, df_test, categorical_features, n_values=140):
    df_train = df_train[categorical_features].astype(str)
    df_test = df_test[categorical_features].astype(str)
    
    categories = []
    for column in tqdm(categorical_features):
        categories.append(list(df_train[column].value_counts().iloc[: n_values - 1].index) + ['Other'])
        values2use = categories[-1]
        df_train[column] = df_train[column].apply(lambda x: x if x in values2use else 'Other')
        df_test[column] = df_test[column].apply(lambda x: x if x in values2use else 'Other')
        
    
    ohe = OneHotEncoder(categories=categories)
    ohe.fit(pd.concat([df_train, df_test]))
    df_train = pd.DataFrame(ohe.transform(df_train).toarray()).astype(np.float16)
    df_test = pd.DataFrame(ohe.transform(df_test).toarray()).astype(np.float16)
    return df_train, df_test

# %%
for feat in categorical_features:
    print(X[feat].nunique())
# Out:
# 5
# 13553
# 500
# 114
# 4
# 119
# 4
# 332
# 74
# 59
# 60
# 2
# 2
# 2
# 3
# 2
# 2
# 2
# 2
# 2

# %%
train_categorical, test_categorical = categorical_encode(X, X_test, categorical_features)
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))

# %%
num_shape = continuous_train.shape[1]
cat_shape = train_categorical.shape[1]

# %%
X = pd.concat([continuous_train, train_categorical], axis=1)
del continuous_train, train_categorical
X_test = pd.concat([continuous_test, test_categorical], axis=1)
del continuous_test, test_categorical

# %%
test_rows = X_test.shape[0]

# %%
X = pd.concat([X, X_test], axis = 0)

# %%
del X_test

# %%
import keras
import random
import tensorflow as tf
import keras.backend as K

from keras.models import Model
from keras.layers import Dense, Input, Dropout, BatchNormalization, Activation
from keras.utils.generic_utils import get_custom_objects
from keras.optimizers import Adam, Nadam
from keras.callbacks import Callback
from sklearn.metrics import roc_auc_score

np.random.seed(42) # NumPy
random.seed(42) # Python
tf.set_random_seed(42) # Tensorflow
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Compatible with tensorflow backend
class roc_callback(Callback):
    def __init__(self,training_data,validation_data):
        self.x = training_data[0]
        self.y = training_data[1]
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]


    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        y_pred_val = self.model.predict(self.x_val)
        roc_val = roc_auc_score(self.y_val, y_pred_val)
        print('\rroc-auc_val: %s' % (str(round(roc_val,4))),end=100*' '+'\n')
        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return
    
def focal_loss(gamma=2., alpha=.25):
    def focal_loss_fixed(y_true, y_pred):
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
        return -K.mean(alpha * K.pow(1. - pt_1, gamma) * K.log(K.epsilon()+pt_1))-K.mean((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0 + K.epsilon()))
    return focal_loss_fixed

def custom_gelu(x):
    return 0.5 * x * (1 + tf.tanh(tf.sqrt(2 / np.pi) * (x + 0.044715 * tf.pow(x, 3))))

get_custom_objects().update({'custom_gelu': Activation(custom_gelu)})
get_custom_objects().update({'focal_loss_fn': focal_loss()})

# %%
from keras.layers import concatenate

# %% [markdown]
# What we will do here is construct a simple autoencoder that will take in our noised numeric and categorical features, concatenate them and then pass them through several dense layers that will then try to predict our original unnoised numeric and categorical features. What this will do is in essence try to learn the relationships between the features and which features should co-occur.

# %%
K.clear_session()
from keras.optimizers import Adam
def create_model():
    num_inp = Input(shape=(num_shape,))
    cat_inp = Input(shape=(cat_shape,))
    inps = concatenate([num_inp, cat_inp])
    x = Dense(512, activation=custom_gelu)(inps)
    x = Dense(256, activation=custom_gelu)(x)
    x = Dense(512, activation = custom_gelu)(x)
    x = Dropout(.2)(x)
    cat_out = Dense(cat_shape, activation = "linear")(x)
    num_out = Dense(num_shape, activation = "linear")(x)
    model = Model(inputs=[num_inp, cat_inp], outputs=[num_out, cat_out])
    model.compile(
        optimizer=Adam(.05, clipnorm = 1, clipvalue = 1),
        loss=["mse", "mse"]
    )
    return model

# %%
model_mse = create_model()

# %%
model_mse.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 50)           0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 911)          0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 961)          0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          492544      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          131584      dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           25650       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 911)          467343      dropout_1[0][0]
# ==================================================================================================
# Total params: 1,248,449
# Trainable params: 1,248,449
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Now we need to invent some realistic noise. As Michael noted in his post he used something he called swap noise. What this is doing is swapping a columns values with other possible values from that column a certain percentage of the time. For example say there is a feature like TransactionAMT. If we used swap noise on that column it would swap 15% of the rows of the TransactionAMT column with other possible values (like swapping 20 for 400, etc.). The model would then see 400 was swapped in and all of the other features around it and it would try to learn that 20 was the real original value and try to correct the various errors we have introduced into the input.

# %%
def inputSwapNoise(arr, p):
    n, m = arr.shape
    idx = range(n)
    swap_n = round(n*p)
    for i in range(m):
        col_vals = np.random.permutation(arr[:, i]) # change the order of the row
        swap_idx = np.random.choice(idx, size= swap_n) # choose row
        arr[swap_idx, i] = np.random.choice(col_vals, size = swap_n) # n*p row and change it 
    return arr

# %% [markdown]
# We will create a small generator so that we can continuously do this swapping and create new samples for the model to see

# %%
def auto_generator(X, swap_rate, batch_size):
    indexes = np.arange(X.shape[0])
    while True:
        np.random.shuffle(indexes)
        num_X = X[indexes[:batch_size], :num_shape] 
        num_y = inputSwapNoise(num_X, swap_rate)
        cat_X = X[indexes[:batch_size], num_shape:] 
        cat_y = inputSwapNoise(cat_X, swap_rate)
        yield [num_y, cat_y], [num_X, cat_X]

# %%
batch_size = 2048

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
auto_ckpt = ModelCheckpoint("ae.model", monitor='loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min', period=1)

# %%
from keras import backend as K


class WarmUpLearningRateScheduler(keras.callbacks.Callback):
    """Warmup learning rate scheduler
    """

    def __init__(self, warmup_batches, init_lr, verbose=0):
        """Constructor for warmup learning rate scheduler

        Arguments:
            warmup_batches {int} -- Number of batch for warmup.
            init_lr {float} -- Learning rate after warmup.

        Keyword Arguments:
            verbose {int} -- 0: quiet, 1: update messages. (default: {0})
        """

        super(WarmUpLearningRateScheduler, self).__init__()
        self.warmup_batches = warmup_batches
        self.init_lr = init_lr
        self.verbose = verbose
        self.batch_count = 0
        self.learning_rates = []

    def on_batch_end(self, batch, logs=None):
        self.batch_count = self.batch_count + 1
        lr = K.get_value(self.model.optimizer.lr)
        self.learning_rates.append(lr)

    def on_batch_begin(self, batch, logs=None):
        if self.batch_count <= self.warmup_batches:
            lr = self.batch_count*self.init_lr/self.warmup_batches
            K.set_value(self.model.optimizer.lr, lr)
            if self.verbose > 0:
                print('\nBatch %05d: WarmUpLearningRateScheduler setting learning '
                      'rate to %s.' % (self.batch_count + 1, lr))
warm_up_lr = WarmUpLearningRateScheduler(400, init_lr=0.005)

# %%
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# Now we will train the autoencoder using our generator for several epochs

# %%
gc.collect()
epochs = 10
train_gen = auto_generator(X.values, .15, batch_size)
hist = model_mse.fit_generator(train_gen, steps_per_epoch=len(X)//batch_size, epochs=epochs,
                           verbose=1, workers=-1, 
                           use_multiprocessing=True,
                              callbacks=[auto_ckpt, warm_up_lr])
# Out:
# Epoch 1/10
#   2/535 [..............................] - ETA: 24:34 - loss: 0.7123 - dense_5_loss: 0.6891 - dense_4_loss: 0.0232
# /opt/conda/lib/python3.6/site-packages/keras/callbacks.py:99: UserWarning: Method on_batch_begin() is slow compared to the batch update (1.394692). Check your callbacks.
#   % delta_t_median)
# 535/535 [==============================] - 363s 678ms/step - loss: 0.0779 - dense_5_loss: 0.0683 - dense_4_loss: 0.0096
#
# Epoch 00001: loss improved from inf to 0.07789, saving model to ae.model
# Epoch 2/10
# 535/535 [==============================] - 354s 661ms/step - loss: 0.0192 - dense_5_loss: 0.0140 - dense_4_loss: 0.0052
#
# Epoch 00002: loss improved from 0.07789 to 0.01916, saving model to ae.model
# Epoch 3/10
# 535/535 [==============================] - 351s 655ms/step - loss: 0.0175 - dense_5_loss: 0.0129 - dense_4_loss: 0.0047
#
# Epoch 00003: loss improved from 0.01916 to 0.01754, saving model to ae.model
# Epoch 4/10
# 535/535 [==============================] - 350s 654ms/step - loss: 0.0166 - dense_5_loss: 0.0123 - dense_4_loss: 0.0044
#
# Epoch 00004: loss improved from 0.01754 to 0.01662, saving model to ae.model
# Epoch 5/10
# 535/535 [==============================] - 349s 653ms/step - loss: 0.0158 - dense_5_loss: 0.0116 - dense_4_loss: 0.0042
#
# Epoch 00005: loss improved from 0.01662 to 0.01579, saving model to ae.model
# Epoch 6/10
# 535/535 [==============================] - 351s 657ms/step - loss: 0.0157 - dense_5_loss: 0.0116 - dense_4_loss: 0.0041
#
# Epoch 00006: loss improved from 0.01579 to 0.01567, saving model to ae.model
# Epoch 7/10
# 535/535 [==============================] - 352s 658ms/step - loss: 0.0155 - dense_5_loss: 0.0115 - dense_4_loss: 0.0040
#
# Epoch 00007: loss improved from 0.01567 to 0.01550, saving model to ae.model
# Epoch 8/10
# 535/535 [==============================] - 348s 650ms/step - loss: 0.0154 - dense_5_loss: 0.0114 - dense_4_loss: 0.0040
#
# Epoch 00008: loss improved from 0.01550 to 0.01544, saving model to ae.model
# Epoch 9/10
# 535/535 [==============================] - 347s 649ms/step - loss: 0.0154 - dense_5_loss: 0.0115 - dense_4_loss: 0.0040
#
# Epoch 00009: loss improved from 0.01544 to 0.01543, saving model to ae.model
# Epoch 10/10
# 476/535 [=========================>....] - ETA: 38s - loss: 0.0155 - dense_5_loss: 0.0115 - dense_4_loss: 0.0040

# %%
del train_gen
gc.collect()
model_mse.load_weights("ae.model")

# %% [markdown]
# Now we will freeze the layers of the autoencoder

# %%
for layer in model_mse.layers:
    layer.trainable = False
model_mse.compile(
    optimizer="adam",
    loss=["mse", "mse"]
)

# %%
model_mse.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 50)           0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 911)          0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 961)          0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          492544      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          131328      dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          131584      dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           25650       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 911)          467343      dropout_1[0][0]
# ==================================================================================================
# Total params: 1,248,449
# Trainable params: 0
# Non-trainable params: 1,248,449
# __________________________________________________________________________________________________

# %% [markdown]
# Next we will make a new model that branches off the previous one. This will take in non-noisy inputs and pass them through the encoding part of the autoencoder and then concatenated all of the middle layers of the encoder and then we will train our classifier based on the features that concatenated encoder outputs.

# %%
def make_model(loss_fn):
    x1 = model_mse.layers[3].output
    x2 = model_mse.layers[4].output
    x3 = model_mse.layers[5].output
    x_conc = concatenate([x1,x2,x3])
    x = Dropout(.5)(x_conc)
    x = Dense(500, activation='relu')(x)
    x = Dropout(.5)(x)
    x = Dense(200, activation='relu')(x)
    x = Dropout(.5)(x)
    x = Dense(100, activation='relu')(x)
    x = Dropout(.5)(x)
    x = Dense(1, activation = 'sigmoid')(x)
    model = Model([model_mse.layers[0].input, model_mse.layers[1].input], x)
    model.compile(
        optimizer="adam",
        loss=[loss_fn]
    )
    return model

# %% [markdown]
# We will train one with binary crossentropy and another with focal loss just like the previous kernel

# %%
fraud_model = make_model("binary_crossentropy")
fraud_focal_model = make_model("focal_loss_fn")

# %% [markdown]
# In the autoencoder we were able to take advantage of being able to train on both the train and test set because the autoencoder was trying to guess inputs rather than our target. No we will split our test set back out because we will be training on those targets for the second phase and we dont have that information for the test set

# %%
X_test = X.iloc[-test_rows:, :]
X = X.iloc[:-test_rows, :]

# %%
import gc
gc.collect()
# Out:
# 0

# %%
split_ind = int(X.shape[0]*0.8)

X_tr = X.iloc[:split_ind]
X_val = X.iloc[split_ind:]

y_tr = y.iloc[:split_ind]
y_val = y.iloc[split_ind:]

del X

# %%
from keras.callbacks import ModelCheckpoint
ckpt = ModelCheckpoint("best_fraud.model", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min', period=1)

# %%
gc.collect()
# Out:
# 0

# %%
fraud_model.fit([X_tr.iloc[:, :num_shape], X_tr.iloc[:, num_shape:]], y_tr, epochs=100, batch_size=2048, 
                validation_data = ([X_val.iloc[:, :num_shape], X_val.iloc[:, num_shape:]], y_val),
               callbacks=[ckpt], verbose = 2)
# Out:
# Train on 472432 samples, validate on 118108 samples
# Epoch 1/100
#  - 18s - loss: 0.1272 - val_loss: 0.1027
#
# Epoch 00001: val_loss improved from inf to 0.10266, saving model to best_fraud.model
# Epoch 2/100
#  - 17s - loss: 0.1065 - val_loss: 0.1007
#
# Epoch 00002: val_loss improved from 0.10266 to 0.10065, saving model to best_fraud.model
# Epoch 3/100
#  - 17s - loss: 0.1034 - val_loss: 0.0997
#
# Epoch 00003: val_loss improved from 0.10065 to 0.09973, saving model to best_fraud.model
# Epoch 4/100
#  - 17s - loss: 0.1014 - val_loss: 0.1019
#
# Epoch 00004: val_loss did not improve from 0.09973
# Epoch 5/100
#  - 17s - loss: 0.0996 - val_loss: 0.0974
#
# Epoch 00005: val_loss improved from 0.09973 to 0.09736, saving model to best_fraud.model
# Epoch 6/100
#  - 17s - loss: 0.0980 - val_loss: 0.0968
#
# Epoch 00006: val_loss improved from 0.09736 to 0.09676, saving model to best_fraud.model
# Epoch 7/100
#  - 17s - loss: 0.0961 - val_loss: 0.0964
#
# Epoch 00007: val_loss improved from 0.09676 to 0.09640, saving model to best_fraud.model
# Epoch 8/100
#  - 17s - loss: 0.0953 - val_loss: 0.0958
#
# Epoch 00008: val_loss improved from 0.09640 to 0.09582, saving model to best_fraud.model
# Epoch 9/100
#  - 17s - loss: 0.0936 - val_loss: 0.0954
#
# Epoch 00009: val_loss improved from 0.09582 to 0.09544, saving model to best_fraud.model
# Epoch 10/100
#  - 17s - loss: 0.0923 - val_loss: 0.0939
#
# Epoch 00010: val_loss improved from 0.09544 to 0.09388, saving model to best_fraud.model
# Epoch 11/100
#  - 17s - loss: 0.0912 - val_loss: 0.0941
#
# Epoch 00011: val_loss did not improve from 0.09388
# Epoch 12/100
#  - 17s - loss: 0.0902 - val_loss: 0.0944
#
# Epoch 00012: val_loss did not improve from 0.09388
# Epoch 13/100
#  - 17s - loss: 0.0891 - val_loss: 0.0941
#
# Epoch 00013: val_loss did not improve from 0.09388
# Epoch 14/100
#  - 17s - loss: 0.0885 - val_loss: 0.0933
#
# Epoch 00014: val_loss improved from 0.09388 to 0.09327, saving model to best_fraud.model
# Epoch 15/100
#  - 17s - loss: 0.0879 - val_loss: 0.0931
#
# Epoch 00015: val_loss improved from 0.09327 to 0.09306, saving model to best_fraud.model
# Epoch 16/100
#  - 17s - loss: 0.0872 - val_loss: 0.0922
#
# Epoch 00016: val_loss improved from 0.09306 to 0.09220, saving model to best_fraud.model
# Epoch 17/100
#  - 17s - loss: 0.0863 - val_loss: 0.0932
#
# Epoch 00017: val_loss did not improve from 0.09220
# Epoch 18/100
#  - 17s - loss: 0.0852 - val_loss: 0.0918
#
# Epoch 00018: val_loss improved from 0.09220 to 0.09181, saving model to best_fraud.model
# Epoch 19/100
#  - 17s - loss: 0.0852 - val_loss: 0.0921
#
# Epoch 00019: val_loss did not improve from 0.09181
# Epoch 20/100
#  - 17s - loss: 0.0845 - val_loss: 0.0926
#
# Epoch 00020: val_loss did not improve from 0.09181
# Epoch 21/100
#  - 17s - loss: 0.0840 - val_loss: 0.0924
#
# Epoch 00021: val_loss did not improve from 0.09181
# Epoch 22/100
#  - 17s - loss: 0.0839 - val_loss: 0.0915
#
# Epoch 00022: val_loss improved from 0.09181 to 0.09153, saving model to best_fraud.model
# Epoch 23/100
#  - 17s - loss: 0.0832 - val_loss: 0.0919
#
# Epoch 00023: val_loss did not improve from 0.09153
# Epoch 24/100
#  - 17s - loss: 0.0828 - val_loss: 0.0917
#
# Epoch 00024: val_loss did not improve from 0.09153
# Epoch 25/100
#  - 17s - loss: 0.0825 - val_loss: 0.0918
#
# Epoch 00025: val_loss did not improve from 0.09153
# Epoch 26/100
#  - 17s - loss: 0.0817 - val_loss: 0.0919
#
# Epoch 00026: val_loss did not improve from 0.09153
# Epoch 27/100
#  - 17s - loss: 0.0811 - val_loss: 0.0917
#
# Epoch 00027: val_loss did not improve from 0.09153
# Epoch 28/100
#  - 17s - loss: 0.0809 - val_loss: 0.0911
#
# Epoch 00028: val_loss improved from 0.09153 to 0.09114, saving model to best_fraud.model
# Epoch 29/100
#  - 17s - loss: 0.0806 - val_loss: 0.0914
#
# Epoch 00029: val_loss did not improve from 0.09114
# Epoch 30/100
#  - 17s - loss: 0.0803 - val_loss: 0.0910
#
# Epoch 00030: val_loss improved from 0.09114 to 0.09096, saving model to best_fraud.model
# Epoch 31/100
#  - 17s - loss: 0.0792 - val_loss: 0.0903
#
# Epoch 00031: val_loss improved from 0.09096 to 0.09032, saving model to best_fraud.model
# Epoch 32/100
#  - 17s - loss: 0.0796 - val_loss: 0.0906
#
# Epoch 00032: val_loss did not improve from 0.09032
# Epoch 33/100
#  - 17s - loss: 0.0793 - val_loss: 0.0906
#
# Epoch 00033: val_loss did not improve from 0.09032
# Epoch 34/100
#  - 17s - loss: 0.0794 - val_loss: 0.0915
#
# Epoch 00034: val_loss did not improve from 0.09032
# Epoch 35/100
#  - 17s - loss: 0.0789 - val_loss: 0.0910
#
# Epoch 00035: val_loss did not improve from 0.09032
# Epoch 36/100
#  - 17s - loss: 0.0783 - val_loss: 0.0908
#
# Epoch 00036: val_loss did not improve from 0.09032
# Epoch 37/100
#  - 17s - loss: 0.0782 - val_loss: 0.0902
#
# Epoch 00037: val_loss improved from 0.09032 to 0.09016, saving model to best_fraud.model
# Epoch 38/100
#  - 17s - loss: 0.0780 - val_loss: 0.0915
#
# Epoch 00038: val_loss did not improve from 0.09016
# Epoch 39/100
#  - 17s - loss: 0.0773 - val_loss: 0.0908
#
# Epoch 00039: val_loss did not improve from 0.09016
# Epoch 40/100
#  - 17s - loss: 0.0775 - val_loss: 0.0912
#
# Epoch 00040: val_loss did not improve from 0.09016
# Epoch 41/100
#  - 17s - loss: 0.0769 - val_loss: 0.0909
#
# Epoch 00041: val_loss did not improve from 0.09016
# Epoch 42/100
#  - 17s - loss: 0.0771 - val_loss: 0.0911
#
# Epoch 00042: val_loss did not improve from 0.09016
# Epoch 43/100
#  - 17s - loss: 0.0768 - val_loss: 0.0910
#
# Epoch 00043: val_loss did not improve from 0.09016
# Epoch 44/100
#  - 17s - loss: 0.0762 - val_loss: 0.0905
#
# Epoch 00044: val_loss did not improve from 0.09016
# Epoch 45/100
#  - 17s - loss: 0.0765 - val_loss: 0.0909
#
# Epoch 00045: val_loss did not improve from 0.09016
# Epoch 46/100
#  - 17s - loss: 0.0762 - val_loss: 0.0904
#
# Epoch 00046: val_loss did not improve from 0.09016
# Epoch 47/100
#  - 17s - loss: 0.0763 - val_loss: 0.0901
#
# Epoch 00047: val_loss improved from 0.09016 to 0.09012, saving model to best_fraud.model
# Epoch 48/100
#  - 17s - loss: 0.0759 - val_loss: 0.0892
#
# Epoch 00048: val_loss improved from 0.09012 to 0.08924, saving model to best_fraud.model
# Epoch 49/100
#  - 17s - loss: 0.0759 - val_loss: 0.0905
#
# Epoch 00049: val_loss did not improve from 0.08924
# Epoch 50/100
#  - 17s - loss: 0.0752 - val_loss: 0.0903
#
# Epoch 00050: val_loss did not improve from 0.08924
# Epoch 51/100
#  - 17s - loss: 0.0752 - val_loss: 0.0902
#
# Epoch 00051: val_loss did not improve from 0.08924
# Epoch 52/100
#  - 17s - loss: 0.0750 - val_loss: 0.0905
#
# Epoch 00052: val_loss did not improve from 0.08924
# Epoch 53/100
#  - 17s - loss: 0.0751 - val_loss: 0.0897
#
# Epoch 00053: val_loss did not improve from 0.08924
# Epoch 54/100
#  - 17s - loss: 0.0746 - val_loss: 0.0906
#
# Epoch 00054: val_loss did not improve from 0.08924
# Epoch 55/100
#  - 17s - loss: 0.0745 - val_loss: 0.0905
#
# Epoch 00055: val_loss did not improve from 0.08924
# Epoch 56/100
#  - 17s - loss: 0.0742 - val_loss: 0.0910
#
# Epoch 00056: val_loss did not improve from 0.08924
# Epoch 57/100
#  - 17s - loss: 0.0743 - val_loss: 0.0902
#
# Epoch 00057: val_loss did not improve from 0.08924
# Epoch 58/100
#  - 17s - loss: 0.0741 - val_loss: 0.0902
#
# Epoch 00058: val_loss did not improve from 0.08924
# Epoch 59/100
#  - 17s - loss: 0.0742 - val_loss: 0.0903
#
# Epoch 00059: val_loss did not improve from 0.08924
# Epoch 60/100
#  - 17s - loss: 0.0738 - val_loss: 0.0907
#
# Epoch 00060: val_loss did not improve from 0.08924
# Epoch 61/100
#  - 17s - loss: 0.0738 - val_loss: 0.0905
#
# Epoch 00061: val_loss did not improve from 0.08924
# Epoch 62/100
#  - 17s - loss: 0.0735 - val_loss: 0.0904
#
# Epoch 00062: val_loss did not improve from 0.08924
# Epoch 63/100
#  - 17s - loss: 0.0737 - val_loss: 0.0900
#
# Epoch 00063: val_loss did not improve from 0.08924
# Epoch 64/100
#  - 17s - loss: 0.0730 - val_loss: 0.0910
#
# Epoch 00064: val_loss did not improve from 0.08924
# Epoch 65/100
#  - 17s - loss: 0.0732 - val_loss: 0.0912
#
# Epoch 00065: val_loss did not improve from 0.08924
# Epoch 66/100
#  - 17s - loss: 0.0728 - val_loss: 0.0910
#
# Epoch 00066: val_loss did not improve from 0.08924
# Epoch 67/100
#  - 17s - loss: 0.0731 - val_loss: 0.0893
#
# Epoch 00067: val_loss did not improve from 0.08924
# Epoch 68/100
#  - 17s - loss: 0.0730 - val_loss: 0.0892
#
# Epoch 00068: val_loss improved from 0.08924 to 0.08922, saving model to best_fraud.model
# Epoch 69/100
#  - 17s - loss: 0.0728 - val_loss: 0.0902
#
# Epoch 00069: val_loss did not improve from 0.08922
# Epoch 70/100
#  - 17s - loss: 0.0722 - val_loss: 0.0910
#
# Epoch 00070: val_loss did not improve from 0.08922
# Epoch 71/100
#  - 17s - loss: 0.0722 - val_loss: 0.0901
#
# Epoch 00071: val_loss did not improve from 0.08922
# Epoch 72/100
#  - 17s - loss: 0.0723 - val_loss: 0.0903
#
# Epoch 00072: val_loss did not improve from 0.08922
# Epoch 73/100
#  - 17s - loss: 0.0720 - val_loss: 0.0899
#
# Epoch 00073: val_loss did not improve from 0.08922
# Epoch 74/100
#  - 17s - loss: 0.0720 - val_loss: 0.0903
#
# Epoch 00074: val_loss did not improve from 0.08922
# Epoch 75/100
#  - 17s - loss: 0.0718 - val_loss: 0.0901
#
# Epoch 00075: val_loss did not improve from 0.08922
# Epoch 76/100
#  - 17s - loss: 0.0719 - val_loss: 0.0904
#
# Epoch 00076: val_loss did not improve from 0.08922
# Epoch 77/100
#  - 17s - loss: 0.0719 - val_loss: 0.0892
#
# Epoch 00077: val_loss did not improve from 0.08922
# Epoch 78/100
#  - 17s - loss: 0.0716 - val_loss: 0.0904
#
# Epoch 00078: val_loss did not improve from 0.08922
# Epoch 79/100
#  - 17s - loss: 0.0716 - val_loss: 0.0899
#
# Epoch 00079: val_loss did not improve from 0.08922
# Epoch 80/100
#  - 17s - loss: 0.0715 - val_loss: 0.0900
#
# Epoch 00080: val_loss did not improve from 0.08922
# Epoch 81/100
#  - 17s - loss: 0.0716 - val_loss: 0.0895
#
# Epoch 00081: val_loss did not improve from 0.08922
# Epoch 82/100
#  - 17s - loss: 0.0709 - val_loss: 0.0893
#
# Epoch 00082: val_loss did not improve from 0.08922
# Epoch 83/100
#  - 16s - loss: 0.0710 - val_loss: 0.0892
#
# Epoch 00083: val_loss improved from 0.08922 to 0.08922, saving model to best_fraud.model
# Epoch 84/100
#  - 16s - loss: 0.0714 - val_loss: 0.0894
#
# Epoch 00084: val_loss did not improve from 0.08922
# Epoch 85/100
#  - 16s - loss: 0.0708 - val_loss: 0.0897
#
# Epoch 00085: val_loss did not improve from 0.08922
# Epoch 86/100
#  - 16s - loss: 0.0710 - val_loss: 0.0891
#
# Epoch 00086: val_loss improved from 0.08922 to 0.08905, saving model to best_fraud.model
# Epoch 87/100
#  - 16s - loss: 0.0710 - val_loss: 0.0901
#
# Epoch 00087: val_loss did not improve from 0.08905
# Epoch 88/100
#  - 16s - loss: 0.0707 - val_loss: 0.0888
#
# Epoch 00088: val_loss improved from 0.08905 to 0.08883, saving model to best_fraud.model
# Epoch 89/100
#  - 16s - loss: 0.0706 - val_loss: 0.0896
#
# Epoch 00089: val_loss did not improve from 0.08883
# Epoch 90/100
#  - 16s - loss: 0.0704 - val_loss: 0.0902
#
# Epoch 00090: val_loss did not improve from 0.08883
# Epoch 91/100
#  - 16s - loss: 0.0702 - val_loss: 0.0893
#
# Epoch 00091: val_loss did not improve from 0.08883
# Epoch 92/100
#  - 16s - loss: 0.0701 - val_loss: 0.0895
#
# Epoch 00092: val_loss did not improve from 0.08883
# Epoch 93/100
#  - 16s - loss: 0.0702 - val_loss: 0.0900
#
# Epoch 00093: val_loss did not improve from 0.08883
# Epoch 94/100
#  - 17s - loss: 0.0695 - val_loss: 0.0904
#
# Epoch 00094: val_loss did not improve from 0.08883
# Epoch 95/100
#  - 16s - loss: 0.0705 - val_loss: 0.0894
#
# Epoch 00095: val_loss did not improve from 0.08883
# Epoch 96/100
#  - 16s - loss: 0.0700 - val_loss: 0.0900
#
# Epoch 00096: val_loss did not improve from 0.08883
# Epoch 97/100
#  - 16s - loss: 0.0696 - val_loss: 0.0894
#
# Epoch 00097: val_loss did not improve from 0.08883
# Epoch 98/100
#  - 16s - loss: 0.0701 - val_loss: 0.0911
#
# Epoch 00098: val_loss did not improve from 0.08883
# Epoch 99/100
#  - 16s - loss: 0.0700 - val_loss: 0.0893
#
# Epoch 00099: val_loss did not improve from 0.08883
# Epoch 100/100
#  - 16s - loss: 0.0697 - val_loss: 0.0889
#
# Epoch 00100: val_loss did not improve from 0.08883

# %%
valid_preds = fraud_model.predict([X_val.iloc[:, :num_shape], X_val.iloc[:, num_shape:]], batch_size = 8000, verbose = True)
roc_auc_score(y_val, valid_preds)
# Out:
# 118108/118108 [==============================] - 1s 10us/step
# 0.9099454737148005

# %%
fraud_model.load_weights("best_fraud.model")
valid_preds = fraud_model.predict([X_val.iloc[:, :num_shape], X_val.iloc[:, num_shape:]], batch_size = 8000, verbose = True)
roc_auc_score(y_val, valid_preds)
# Out:
# 118108/118108 [==============================] - 1s 9us/step
# 0.9075298386870712

# %%
ckpt2 = ModelCheckpoint("best_fraud_focal.model", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='min', period=1)
fraud_focal_model.fit([X_tr.iloc[:, :num_shape], X_tr.iloc[:, num_shape:]], y_tr, epochs=100, batch_size=2048, 
                validation_data = ([X_val.iloc[:, :num_shape], X_val.iloc[:, num_shape:]], y_val),
               callbacks=[ckpt2], verbose = 2)
# Out:
# Train on 472432 samples, validate on 118108 samples
# Epoch 1/100
#  - 18s - loss: 0.0150 - val_loss: 0.0110
#
# Epoch 00001: val_loss improved from inf to 0.01103, saving model to best_fraud_focal.model
# Epoch 2/100
#  - 17s - loss: 0.0110 - val_loss: 0.0107
#
# Epoch 00002: val_loss improved from 0.01103 to 0.01073, saving model to best_fraud_focal.model
# Epoch 3/100
#  - 17s - loss: 0.0107 - val_loss: 0.0101
#
# Epoch 00003: val_loss improved from 0.01073 to 0.01010, saving model to best_fraud_focal.model
# Epoch 4/100
#  - 17s - loss: 0.0104 - val_loss: 0.0100
#
# Epoch 00004: val_loss improved from 0.01010 to 0.01004, saving model to best_fraud_focal.model
# Epoch 5/100
#  - 17s - loss: 0.0103 - val_loss: 0.0101
#
# Epoch 00005: val_loss did not improve from 0.01004
# Epoch 6/100
#  - 17s - loss: 0.0101 - val_loss: 0.0100
#
# Epoch 00006: val_loss improved from 0.01004 to 0.01003, saving model to best_fraud_focal.model
# Epoch 7/100
#  - 17s - loss: 0.0099 - val_loss: 0.0098
#
# Epoch 00007: val_loss improved from 0.01003 to 0.00983, saving model to best_fraud_focal.model
# Epoch 8/100
#  - 17s - loss: 0.0097 - val_loss: 0.0097
#
# Epoch 00008: val_loss improved from 0.00983 to 0.00968, saving model to best_fraud_focal.model
# Epoch 9/100
#  - 17s - loss: 0.0096 - val_loss: 0.0095
#
# Epoch 00009: val_loss improved from 0.00968 to 0.00953, saving model to best_fraud_focal.model
# Epoch 10/100
#  - 17s - loss: 0.0094 - val_loss: 0.0096
#
# Epoch 00010: val_loss did not improve from 0.00953
# Epoch 11/100
#  - 17s - loss: 0.0093 - val_loss: 0.0093
#
# Epoch 00011: val_loss improved from 0.00953 to 0.00933, saving model to best_fraud_focal.model
# Epoch 12/100
#  - 17s - loss: 0.0092 - val_loss: 0.0094
#
# Epoch 00012: val_loss did not improve from 0.00933
# Epoch 13/100
#  - 17s - loss: 0.0091 - val_loss: 0.0093
#
# Epoch 00013: val_loss improved from 0.00933 to 0.00927, saving model to best_fraud_focal.model
# Epoch 14/100
#  - 17s - loss: 0.0090 - val_loss: 0.0093
#
# Epoch 00014: val_loss did not improve from 0.00927
# Epoch 15/100
#  - 17s - loss: 0.0089 - val_loss: 0.0093
#
# Epoch 00015: val_loss improved from 0.00927 to 0.00925, saving model to best_fraud_focal.model
# Epoch 16/100
#  - 17s - loss: 0.0088 - val_loss: 0.0092
#
# Epoch 00016: val_loss improved from 0.00925 to 0.00920, saving model to best_fraud_focal.model
# Epoch 17/100
#  - 17s - loss: 0.0088 - val_loss: 0.0093
#
# Epoch 00017: val_loss did not improve from 0.00920
# Epoch 18/100
#  - 17s - loss: 0.0087 - val_loss: 0.0092
#
# Epoch 00018: val_loss improved from 0.00920 to 0.00919, saving model to best_fraud_focal.model
# Epoch 19/100
#  - 17s - loss: 0.0086 - val_loss: 0.0092
#
# Epoch 00019: val_loss improved from 0.00919 to 0.00916, saving model to best_fraud_focal.model
# Epoch 20/100
#  - 17s - loss: 0.0085 - val_loss: 0.0091
#
# Epoch 00020: val_loss improved from 0.00916 to 0.00910, saving model to best_fraud_focal.model
# Epoch 21/100
#  - 17s - loss: 0.0085 - val_loss: 0.0091
#
# Epoch 00021: val_loss improved from 0.00910 to 0.00906, saving model to best_fraud_focal.model
# Epoch 22/100
#  - 17s - loss: 0.0084 - val_loss: 0.0091
#
# Epoch 00022: val_loss did not improve from 0.00906
# Epoch 23/100
#  - 17s - loss: 0.0084 - val_loss: 0.0090
#
# Epoch 00023: val_loss improved from 0.00906 to 0.00904, saving model to best_fraud_focal.model
# Epoch 24/100
#  - 17s - loss: 0.0083 - val_loss: 0.0090
#
# Epoch 00024: val_loss improved from 0.00904 to 0.00901, saving model to best_fraud_focal.model
# Epoch 25/100
#  - 17s - loss: 0.0082 - val_loss: 0.0091
#
# Epoch 00025: val_loss did not improve from 0.00901
# Epoch 26/100
#  - 17s - loss: 0.0082 - val_loss: 0.0092
#
# Epoch 00026: val_loss did not improve from 0.00901
# Epoch 27/100
#  - 17s - loss: 0.0081 - val_loss: 0.0091
#
# Epoch 00027: val_loss did not improve from 0.00901
# Epoch 28/100
#  - 17s - loss: 0.0082 - val_loss: 0.0090
#
# Epoch 00028: val_loss did not improve from 0.00901
# Epoch 29/100
#  - 18s - loss: 0.0081 - val_loss: 0.0089
#
# Epoch 00029: val_loss improved from 0.00901 to 0.00890, saving model to best_fraud_focal.model
# Epoch 30/100
#  - 17s - loss: 0.0081 - val_loss: 0.0090
#
# Epoch 00030: val_loss did not improve from 0.00890
# Epoch 31/100
#  - 17s - loss: 0.0080 - val_loss: 0.0090
#
# Epoch 00031: val_loss did not improve from 0.00890
# Epoch 32/100
#  - 17s - loss: 0.0080 - val_loss: 0.0091
#
# Epoch 00032: val_loss did not improve from 0.00890
# Epoch 33/100
#  - 17s - loss: 0.0079 - val_loss: 0.0090
#
# Epoch 00033: val_loss did not improve from 0.00890
# Epoch 34/100
#  - 17s - loss: 0.0079 - val_loss: 0.0089
#
# Epoch 00034: val_loss did not improve from 0.00890
# Epoch 35/100
#  - 17s - loss: 0.0079 - val_loss: 0.0089
#
# Epoch 00035: val_loss improved from 0.00890 to 0.00889, saving model to best_fraud_focal.model
# Epoch 36/100
#  - 17s - loss: 0.0079 - val_loss: 0.0090
#
# Epoch 00036: val_loss did not improve from 0.00889
# Epoch 37/100
#  - 17s - loss: 0.0078 - val_loss: 0.0089
#
# Epoch 00037: val_loss improved from 0.00889 to 0.00888, saving model to best_fraud_focal.model
# Epoch 38/100
#  - 17s - loss: 0.0078 - val_loss: 0.0088
#
# Epoch 00038: val_loss improved from 0.00888 to 0.00885, saving model to best_fraud_focal.model
# Epoch 39/100
#  - 17s - loss: 0.0078 - val_loss: 0.0089
#
# Epoch 00039: val_loss did not improve from 0.00885
# Epoch 40/100
#  - 17s - loss: 0.0077 - val_loss: 0.0089
#
# Epoch 00040: val_loss did not improve from 0.00885
# Epoch 41/100
#  - 17s - loss: 0.0077 - val_loss: 0.0089
#
# Epoch 00041: val_loss did not improve from 0.00885
# Epoch 42/100
#  - 17s - loss: 0.0078 - val_loss: 0.0089
#
# Epoch 00042: val_loss did not improve from 0.00885
# Epoch 43/100
#  - 17s - loss: 0.0077 - val_loss: 0.0090
#
# Epoch 00043: val_loss did not improve from 0.00885
# Epoch 44/100
#  - 17s - loss: 0.0077 - val_loss: 0.0090
#
# Epoch 00044: val_loss did not improve from 0.00885
# Epoch 45/100
#  - 17s - loss: 0.0076 - val_loss: 0.0090
#
# Epoch 00045: val_loss did not improve from 0.00885
# Epoch 46/100
#  - 17s - loss: 0.0076 - val_loss: 0.0089
#
# Epoch 00046: val_loss did not improve from 0.00885
# Epoch 47/100
#  - 18s - loss: 0.0076 - val_loss: 0.0089
#
# Epoch 00047: val_loss did not improve from 0.00885
# Epoch 48/100
#  - 17s - loss: 0.0076 - val_loss: 0.0089
#
# Epoch 00048: val_loss did not improve from 0.00885
# Epoch 49/100
#  - 17s - loss: 0.0076 - val_loss: 0.0090
#
# Epoch 00049: val_loss did not improve from 0.00885
# Epoch 50/100
#  - 17s - loss: 0.0076 - val_loss: 0.0089
#
# Epoch 00050: val_loss did not improve from 0.00885
# Epoch 51/100
#  - 17s - loss: 0.0076 - val_loss: 0.0089
#
# Epoch 00051: val_loss did not improve from 0.00885
# Epoch 52/100
#  - 17s - loss: 0.0075 - val_loss: 0.0088
#
# Epoch 00052: val_loss improved from 0.00885 to 0.00884, saving model to best_fraud_focal.model
# Epoch 53/100
#  - 17s - loss: 0.0075 - val_loss: 0.0090
#
# Epoch 00053: val_loss did not improve from 0.00884
# Epoch 54/100
#  - 17s - loss: 0.0074 - val_loss: 0.0089
#
# Epoch 00054: val_loss did not improve from 0.00884
# Epoch 55/100
#  - 17s - loss: 0.0075 - val_loss: 0.0088
#
# Epoch 00055: val_loss improved from 0.00884 to 0.00884, saving model to best_fraud_focal.model
# Epoch 56/100
#  - 17s - loss: 0.0074 - val_loss: 0.0089
#
# Epoch 00056: val_loss did not improve from 0.00884
# Epoch 57/100
#  - 17s - loss: 0.0074 - val_loss: 0.0089
#
# Epoch 00057: val_loss did not improve from 0.00884
# Epoch 58/100
#  - 17s - loss: 0.0074 - val_loss: 0.0089
#
# Epoch 00058: val_loss did not improve from 0.00884
# Epoch 59/100
#  - 17s - loss: 0.0074 - val_loss: 0.0088
#
# Epoch 00059: val_loss improved from 0.00884 to 0.00881, saving model to best_fraud_focal.model
# Epoch 60/100
#  - 17s - loss: 0.0073 - val_loss: 0.0089
#
# Epoch 00060: val_loss did not improve from 0.00881
# Epoch 61/100
#  - 17s - loss: 0.0074 - val_loss: 0.0089
#
# Epoch 00061: val_loss did not improve from 0.00881
# Epoch 62/100
#  - 17s - loss: 0.0074 - val_loss: 0.0089
#
# Epoch 00062: val_loss did not improve from 0.00881
# Epoch 63/100
#  - 17s - loss: 0.0074 - val_loss: 0.0088
#
# Epoch 00063: val_loss did not improve from 0.00881
# Epoch 64/100
#  - 17s - loss: 0.0073 - val_loss: 0.0089
#
# Epoch 00064: val_loss did not improve from 0.00881
# Epoch 65/100
#  - 17s - loss: 0.0073 - val_loss: 0.0088
#
# Epoch 00065: val_loss improved from 0.00881 to 0.00879, saving model to best_fraud_focal.model
# Epoch 66/100
#  - 17s - loss: 0.0073 - val_loss: 0.0089
#
# Epoch 00066: val_loss did not improve from 0.00879
# Epoch 67/100
#  - 17s - loss: 0.0073 - val_loss: 0.0090
#
# Epoch 00067: val_loss did not improve from 0.00879
# Epoch 68/100
#  - 17s - loss: 0.0073 - val_loss: 0.0090
#
# Epoch 00068: val_loss did not improve from 0.00879
# Epoch 69/100
#  - 17s - loss: 0.0072 - val_loss: 0.0091
#
# Epoch 00069: val_loss did not improve from 0.00879
# Epoch 70/100
#  - 17s - loss: 0.0072 - val_loss: 0.0089
#
# Epoch 00070: val_loss did not improve from 0.00879
# Epoch 71/100
#  - 17s - loss: 0.0073 - val_loss: 0.0089
#
# Epoch 00071: val_loss did not improve from 0.00879
# Epoch 72/100
#  - 17s - loss: 0.0072 - val_loss: 0.0089
#
# Epoch 00072: val_loss did not improve from 0.00879
# Epoch 73/100
#  - 17s - loss: 0.0072 - val_loss: 0.0089
#
# Epoch 00073: val_loss did not improve from 0.00879
# Epoch 74/100
#  - 17s - loss: 0.0072 - val_loss: 0.0089
#
# Epoch 00074: val_loss did not improve from 0.00879
# Epoch 75/100
#  - 17s - loss: 0.0072 - val_loss: 0.0088
#
# Epoch 00075: val_loss did not improve from 0.00879
# Epoch 76/100
#  - 17s - loss: 0.0072 - val_loss: 0.0087
#
# Epoch 00076: val_loss improved from 0.00879 to 0.00873, saving model to best_fraud_focal.model
# Epoch 77/100
#  - 17s - loss: 0.0072 - val_loss: 0.0088
#
# Epoch 00077: val_loss did not improve from 0.00873
# Epoch 78/100
#  - 17s - loss: 0.0072 - val_loss: 0.0089
#
# Epoch 00078: val_loss did not improve from 0.00873
# Epoch 79/100
#  - 17s - loss: 0.0072 - val_loss: 0.0089
#
# Epoch 00079: val_loss did not improve from 0.00873
# Epoch 80/100
#  - 17s - loss: 0.0072 - val_loss: 0.0090
#
# Epoch 00080: val_loss did not improve from 0.00873
# Epoch 81/100
#  - 17s - loss: 0.0072 - val_loss: 0.0089
#
# Epoch 00081: val_loss did not improve from 0.00873
# Epoch 82/100
#  - 17s - loss: 0.0071 - val_loss: 0.0088
#
# Epoch 00082: val_loss did not improve from 0.00873
# Epoch 83/100
#  - 18s - loss: 0.0071 - val_loss: 0.0090
#
# Epoch 00083: val_loss did not improve from 0.00873
# Epoch 84/100
#  - 17s - loss: 0.0071 - val_loss: 0.0089
#
# Epoch 00084: val_loss did not improve from 0.00873
# Epoch 85/100
#  - 17s - loss: 0.0071 - val_loss: 0.0089
#
# Epoch 00085: val_loss did not improve from 0.00873
# Epoch 86/100
#  - 17s - loss: 0.0071 - val_loss: 0.0089
#
# Epoch 00086: val_loss did not improve from 0.00873
# Epoch 87/100
#  - 17s - loss: 0.0072 - val_loss: 0.0088
#
# Epoch 00087: val_loss did not improve from 0.00873
# Epoch 88/100
#  - 17s - loss: 0.0071 - val_loss: 0.0088
#
# Epoch 00088: val_loss did not improve from 0.00873
# Epoch 89/100
#  - 17s - loss: 0.0071 - val_loss: 0.0089
#
# Epoch 00089: val_loss did not improve from 0.00873
# Epoch 90/100
#  - 17s - loss: 0.0070 - val_loss: 0.0089
#
# Epoch 00090: val_loss did not improve from 0.00873
# Epoch 91/100
#  - 17s - loss: 0.0071 - val_loss: 0.0088
#
# Epoch 00091: val_loss did not improve from 0.00873
# Epoch 92/100
#  - 17s - loss: 0.0071 - val_loss: 0.0090
#
# Epoch 00092: val_loss did not improve from 0.00873
# Epoch 93/100
#  - 17s - loss: 0.0070 - val_loss: 0.0090
#
# Epoch 00093: val_loss did not improve from 0.00873
# Epoch 94/100
#  - 17s - loss: 0.0070 - val_loss: 0.0089
#
# Epoch 00094: val_loss did not improve from 0.00873
# Epoch 95/100
#  - 17s - loss: 0.0070 - val_loss: 0.0091
#
# Epoch 00095: val_loss did not improve from 0.00873
# Epoch 96/100
#  - 17s - loss: 0.0070 - val_loss: 0.0089
#
# Epoch 00096: val_loss did not improve from 0.00873
# Epoch 97/100
#  - 17s - loss: 0.0070 - val_loss: 0.0089
#
# Epoch 00097: val_loss did not improve from 0.00873
# Epoch 98/100
#  - 17s - loss: 0.0070 - val_loss: 0.0089
#
# Epoch 00098: val_loss did not improve from 0.00873
# Epoch 99/100
#  - 17s - loss: 0.0070 - val_loss: 0.0089
#
# Epoch 00099: val_loss did not improve from 0.00873
# Epoch 100/100
#  - 17s - loss: 0.0070 - val_loss: 0.0089
#
# Epoch 00100: val_loss did not improve from 0.00873

# %%
fraud_model.load_weights("best_fraud.model")

# %%
fraud_focal_model.load_weights("best_fraud_focal.model")

# %%
valid_preds = fraud_model.predict([X_val.iloc[:, :num_shape], X_val.iloc[:, num_shape:]], batch_size = 8000, verbose = True)
roc_auc_score(y_val, valid_preds)
# Out:
# 118108/118108 [==============================] - 1s 9us/step
# 0.9075298386870712

# %%
from scipy.stats import rankdata, spearmanr
valid_preds = fraud_model.predict([X_val.iloc[:, :num_shape], X_val.iloc[:, num_shape:]], batch_size = 8000, verbose = True)
valid_preds2 = fraud_focal_model.predict([X_val.iloc[:, :num_shape], X_val.iloc[:, num_shape:]], batch_size = 8000, verbose = True)
score = roc_auc_score(y_val, valid_preds)
score2 = roc_auc_score(y_val, valid_preds2)
score_avg = roc_auc_score(y_val, (.5*valid_preds) + (.5*valid_preds2))
print(score)
print(score2)
print(score_avg)
print('Rank averaging: ', roc_auc_score(y_val, rankdata(valid_preds, method='dense') + rankdata(valid_preds2, method='dense')))
# Out:
# 118108/118108 [==============================] - 1s 8us/step
# 118108/118108 [==============================] - 1s 9us/step
# 0.9075298386870712
# 0.9096795315411486
# 0.9114832142249558
# Rank averaging:  0.9112716849322833

# %%
X_tr = pd.concat([X_tr, X_val, X_val, X_val, X_val], axis = 0)
y_tr = pd.concat([y_tr, y_val, y_val, y_val, y_val], axis = 0)

# %%
fraud_model.fit([X_tr.iloc[:, :num_shape], X_tr.iloc[:, num_shape:]], y_tr, epochs=10, batch_size=2048)
fraud_focal_model.fit([X_tr.iloc[:, :num_shape], X_tr.iloc[:, num_shape:]], y_tr, epochs=10, batch_size=2048)
# Out:
# Epoch 1/10
# 944864/944864 [==============================] - 32s 33us/step - loss: 0.0824
# Epoch 2/10
# 944864/944864 [==============================] - 32s 33us/step - loss: 0.0792
# Epoch 3/10
# 944864/944864 [==============================] - 32s 33us/step - loss: 0.0777
# Epoch 4/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0763
# Epoch 5/10
# 944864/944864 [==============================] - 32s 33us/step - loss: 0.0756
# Epoch 6/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0750
# Epoch 7/10
# 944864/944864 [==============================] - 32s 34us/step - loss: 0.0742
# Epoch 8/10
# 944864/944864 [==============================] - 32s 33us/step - loss: 0.0739
# Epoch 9/10
# 944864/944864 [==============================] - 32s 33us/step - loss: 0.0734
# Epoch 10/10
# 944864/944864 [==============================] - 32s 34us/step - loss: 0.0727
# Epoch 1/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0082
# Epoch 2/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0079
# Epoch 3/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0078
# Epoch 4/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0077
# Epoch 5/10
# 944864/944864 [==============================] - 31s 32us/step - loss: 0.0076
# Epoch 6/10
# 944864/944864 [==============================] - 31s 32us/step - loss: 0.0075
# Epoch 7/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0074
# Epoch 8/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0074
# Epoch 9/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0073
# Epoch 10/10
# 944864/944864 [==============================] - 31s 33us/step - loss: 0.0073

# %%
test_preds = fraud_model.predict([X_test.iloc[:, :num_shape], X_test.iloc[:, num_shape:]], batch_size = 8000)
test_preds2 = fraud_focal_model.predict([X_test.iloc[:, :num_shape], X_test.iloc[:, num_shape:]], batch_size = 8000)

# %%
sub['isFraud'] = rankdata(test_preds, method='dense') + rankdata(test_preds2, method='dense')
sub.isFraud = sub.isFraud/sub.isFraud.max()
sub.to_csv('submission.csv', index=False)
