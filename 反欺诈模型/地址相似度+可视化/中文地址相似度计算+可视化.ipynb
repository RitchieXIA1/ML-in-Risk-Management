# %% [markdown]
# 环境清单
#
# numpy
#
# pandas
#
# cpca    提取中文地址的库
#
# jieba   分词工具
#
# gensim   文本处理库

# %%
#pip install folium 可视化需要的库，可以不安装
import numpy as np
import pandas as pd
import time
import cpca 
from cpca import drawer
import jieba
from gensim import corpora, models, similarities
import warnings
warnings.filterwarnings("ignore")

# %%
def read_data(path):
    #导入数据,并对数据做一些处理
    df = pd.read_excel("{}.xlsx".format(path), dtype={'公司代码': 'str'})
    addr_df = df[["公司代码", "公司简称", "注册地址"]]
    addr_df["注册地址"]= addr_df["注册地址"].apply(lambda x: str(x).strip())
    return addr_df

# %%
def get_dataset(addr_df):
    '''
    #对地址做一个标准化处理,其中导入cpca的包进行处理
    考虑到了区为空和区不为空两种情况
    '''
    start = time.time()
    
    location_str = []
    for i in addr_df['注册地址']:
        location_str.append(i.strip())
        
    addr_cp = cpca.transform(location_str)
    
    #给结果表拼接唯一识别代码
    e_data = addr_df[["公司代码", "公司简称"]]
    addr_cpca = pd.concat([e_data, addr_cp], axis=1)
    
    #1.区不为空
    addr_cpca_1 = addr_cpca[(addr_cpca['省']!= '')&(addr_cpca['市']!= '') & (addr_cpca['区']!= '')]
    addr_cpca_1= addr_cpca_1.dropna()
    
    addr_cpca_11= addr_cpca_1[(addr_cpca['地址']!='')]
    addr_cpca_12= addr_cpca_11. dropna(subset=['地址'])
    
    #将前三个字段完全拼接在一起进行分组然后组内进行相似度分析
    addr_cpca_12['省市区'] = addr_cpca_12['省'] + addr_cpca_12['市'] + addr_cpca_12['区']
    
    addr_cpca_12['省市区长度']=addr_cpca_12['省市区'].apply(lambda x: len(x))
    count_1 = addr_cpca_12['省市区'].value_counts().reset_index()
    count_1= count_1.rename(columns={'index':'省市区', '省市区':'个数'})
    
    count_delete_1= count_1[count_1['个数']==1]
    dataset_1 = pd.merge(addr_cpca_12, count_delete_1, on = '省市区', how = 'left')
    dataset_1= dataset_1[dataset_1['个数']!=1]
    
    #2.区为空  
    addr_cpca_2 = addr_cpca[(addr_cpca['省']!= '')&(addr_cpca['市']!= '') & (addr_cpca['区']== '')]
    addr_cpca_2 = addr_cpca_2.dropna()
    
    addr_cpca_21= addr_cpca_2[(addr_cpca['地址']!='')]
    addr_cpca_22= addr_cpca_21. dropna(subset=['地址'])
    
    #将前三个字段完全拼接在一起进行分组然后组内进行相似度分析
    addr_cpca_22['省市区'] = addr_cpca_22['省'] + addr_cpca_22['市']
    
    addr_cpca_22['省市区长度']=addr_cpca_22['省市区'].apply(lambda x: len(x))
    count_2 = addr_cpca_22['省市区'].value_counts().reset_index()
    count_2= count_2.rename(columns={'index':'省市区', '省市区':'个数'})
    
    count_delete_2 = count_2[count_2['个数']==1]
    dataset_2 = pd.merge(addr_cpca_22, count_delete_2, on = '省市区', how = 'left')
    dataset_2 = dataset_2[dataset_2['个数']!=1]
    
    
    print("Time used:", round(time.time()-start), "s")
    
    return dataset_1, dataset_2

# %%
def cal_similar(doc_goal, document, ssim = 0.1):
#def cal_similar(doc_goai, document):
    '''
    分词;计算文本相似度，这里使用TF-IDF模型，如果有必要也可以使用其他文本向量化模型
    doc_goal,短文本，目标文档
    document,多个文本，被比较的多个文档
    '''
    all_doc_list=[]
    for doc in document:
        doc= "".join(doc)
        doc_list=[word for word in jieba.cut(doc)]
        all_doc_list.append(doc_list)

    #目标文档
    doc_goal = "".join(doc_goal)
    doc_goal_list = [word for word in jieba.cut(doc_goal)]
    
    #被比较的多个文档
    dictionary = corpora.Dictionary(all_doc_list)  #先用dictionary方法获词袋
    corpus = [dictionary.doc2bow(doc) for doc in all_doc_list]  #使用doc2bow制作预料库
    
    #目标文档
    doc_goal_vec = dictionary.doc2bow(doc_goal_list)
    tfidf = models.TfidfModel(corpus)#使用TF-DF模型对料库建模
    index = similarities.SparseMatrixSimilarity(tfidf[corpus], num_features = len(dictionary.keys()))#对每个目标文档,分析测文档的相似度
    
    #开始比较
    sims = index[tfidf[doc_goal_vec]]
    #similary= sorted(enumerate(sims),key=lambda item: -item[1])#根据相似度排序
    
    addr_dict={"被比较地址": document, "相似度": list(sims)}
    similary = pd.DataFrame(addr_dict)
    similary["目标地址"] = doc_goal
    similary_data = similary[["目标地址", "被比较地址", "相似度"]]
    similary_data= similary_data[similary_data["相似度"]>=ssim]
    
    return similary_data

# %%
def cycle_first(single_data):
    
    single_value = single_data.loc[:,["公司代码","地址"]].values #提取地址和ID
    
    cycle_data = pd. DataFrame([])
    for key, value in enumerate(single_value):
        if key < len(single_data)-1:
            doc_goal=list(value)[1:]
            document=list(single_data["地址"])[key+1:]
            cycle = cal_similar(doc_goal, document, ssim=0)
            cycle['目标地址代码'] = list(single_data["公司代码"])[key]
            cycle['目标地址省市区'] = list(single_data["省市区"])[key]
            cycle['被比较地址代码'] = list(single_data["公司代码"])[key+1:]
            cycle['被比较地址省市区'] = list(single_data["省市区"])[key+1:]
            cycle = cycle[["目标地址省市区","目标地址代码","目标地址","被比较地址省市区","被比较地址代码", "被比较地址", "相似度"]]
            #print("循环第",key,"个地址,得到表的行数,",len(cycle),",当前子循环计算进度,",key/len(cycle))
        cycle_data = cycle_data.append(cycle)
        cycle_data = cycle_data.drop_duplicates()
        cycle_data['adcode'] = single_data['adcode'].values[0]
   
    return cycle_data


def get_collect(dataset):
    '''
    计算同一区内地址的相似度，减少计算成本
    可以修改为计算同一个人的地址相似度
    '''
    start = time.time()
    
    #获取单个省市区的文档
    collect_data = pd.DataFrame([])
    ssq=list(set(dataset['省市区']))#如果要改成计算同一个人相似度，则这里改为身份证号
    for v, word in enumerate(ssq):
        single_data = dataset[dataset['省市区'] == word]
        print("循环第",v,"个省市区地址为:",word,",当前此区地址有:",len(single_data),",当前计算进度为:{:.1f}%" .format(v*100/len(ssq)))
        cycle_data = cycle_first(single_data)
        
        collect_data = collect_data.append(cycle_data)#将每个市区得到的结果放入一张表
        
        print("Time: %s" %time.ctime())
        print("-----------------------------------------------------------------------")
    
    print("Time used:",(time.time() - start), "s")
    
    return collect_data

# %%
df1 =read_data('创业板')
df2 = read_data('中小企业板')
df = pd.concat([df1,df2],axis=0,ignore_index=True)

# %%
df
# Out:
#         公司代码  公司简称                                        注册地址
# 0     300001   特锐德                            山东省青岛市崂山区松岭路336号
# 1     300002  神州泰岳                 北京市海淀区万泉庄路28号万柳新贵大厦A座6层601室
# 2     300003  乐普医疗                                北京市昌平区超前路37号
# 3     300004  南风股份                     广东省佛山市南海区小塘三环西路(狮南段)31号
# 4     300005   探路者                         北京市昌平区科技园区永安路26号609
# ...      ...   ...                                         ...
# 1768  002986  宇新股份         湖南省长沙市雨花区迎新路868号德思勤城市广场第A-2地块第7栋16层
# 1769  002987   京北方                            北京市海淀区西三环北路25号7层
# 1770  002988  豪美新材                        广东省清远市高新技术产业开发区泰基工业城
# 1771  002990  盛视科技  广东省深圳市福田区沙头街道天安社区泰然十路天安创新科技广场二期东座1601、1605
# 1772  003816  中国广核                广东省深圳市福田区深南大道2002号中广核大厦南楼18楼
#
# [1773 rows x 3 columns]

# %%
dataset_1, dataset_2  =get_dataset(df)
collect_data_1 = get_collect(dataset_1)
collect_data_1.sort_values(by=["相似度"], ascending=[False],inplace=True)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Time used: 0 s
# 循环第 0 个省市区地址为: 北京市市辖区门头沟区 ,当前此区地址有: 2 ,当前计算进度为:0.0%
# Loading model cost 0.471 seconds.
# Prefix dict has been built successfully.
# Time: Wed Apr  6 15:49:42 2022
# -----------------------------------------------------------------------
# 循环第 1 个省市区地址为: 广东省惠州市惠阳区 ,当前此区地址有: 2 ,当前计算进度为:0.5%
# Time: Wed Apr  6 15:49:42 2022
# -----------------------------------------------------------------------
# 循环第 2 个省市区地址为: 浙江省绍兴市柯桥区 ,当前此区地址有: 4 ,当前计算进度为:1.1%
# Time: Wed Apr  6 15:49:42 2022
# -----------------------------------------------------------------------
# 循环第 3 个省市区地址为: 福建省福州市鼓楼区 ,当前此区地址有: 7 ,当前计算进度为:1.6%
# Time: Wed Apr  6 15:49:43 2022
# -----------------------------------------------------------------------
# 循环第 4 个省市区地址为: 云南省昆明市官渡区 ,当前此区地址有: 2 ,当前计算进度为:2.2%
# Time: Wed Apr  6 15:49:43 2022
# -----------------------------------------------------------------------
# 循环第 5 个省市区地址为: 江苏省无锡市滨湖区 ,当前此区地址有: 6 ,当前计算进度为:2.7%
# Time: Wed Apr  6 15:49:43 2022
# -----------------------------------------------------------------------
# 循环第 6 个省市区地址为: 上海市市辖区宝山区 ,当前此区地址有: 2 ,当前计算进度为:3.3%
# Time: Wed Apr  6 15:49:43 2022
# -----------------------------------------------------------------------
# 循环第 7 个省市区地址为: 广西壮族自治区桂林市临桂区 ,当前此区地址有: 2 ,当前计算进度为:3.8%
# Time: Wed Apr  6 15:49:43 2022
# -----------------------------------------------------------------------
# 循环第 8 个省市区地址为: 浙江省宁波市慈溪市 ,当前此区地址有: 5 ,当前计算进度为:4.4%
# Time: Wed Apr  6 15:49:43 2022
# -----------------------------------------------------------------------
# 循环第 9 个省市区地址为: 四川省成都市金牛区 ,当前此区地址有: 3 ,当前计算进度为:4.9%
# Time: Wed Apr  6 15:49:43 2022
# -----------------------------------------------------------------------
# 循环第 10 个省市区地址为: 浙江省宁波市象山县 ,当前此区地址有: 4 ,当前计算进度为:5.5%
# Time: Wed Apr  6 15:49:43 2022
# -----------------------------------------------------------------------
# 循环第 11 个省市区地址为: 广东省深圳市宝安区 ,当前此区地址有: 27 ,当前计算进度为:6.0%
# Time: Wed Apr  6 15:49:44 2022
# -----------------------------------------------------------------------
# 循环第 12 个省市区地址为: 甘肃省兰州市榆中县 ,当前此区地址有: 2 ,当前计算进度为:6.6%
# Time: Wed Apr  6 15:49:44 2022
# -----------------------------------------------------------------------
# 循环第 13 个省市区地址为: 江苏省无锡市江阴市 ,当前此区地址有: 12 ,当前计算进度为:7.1%
# Time: Wed Apr  6 15:49:44 2022
# -----------------------------------------------------------------------
# 循环第 14 个省市区地址为: 广东省广州市天河区 ,当前此区地址有: 14 ,当前计算进度为:7.7%
# Time: Wed Apr  6 15:49:44 2022
# -----------------------------------------------------------------------
# 循环第 15 个省市区地址为: 福建省龙岩市新罗区 ,当前此区地址有: 2 ,当前计算进度为:8.2%
# Time: Wed Apr  6 15:49:44 2022
# -----------------------------------------------------------------------
# 循环第 16 个省市区地址为: 浙江省台州市天台县 ,当前此区地址有: 3 ,当前计算进度为:8.8%
# Time: Wed Apr  6 15:49:44 2022
# -----------------------------------------------------------------------
# 循环第 17 个省市区地址为: 浙江省台州市临海市 ,当前此区地址有: 4 ,当前计算进度为:9.3%
# Time: Wed Apr  6 15:49:44 2022
# -----------------------------------------------------------------------
# 循环第 18 个省市区地址为: 上海市市辖区松江区 ,当前此区地址有: 6 ,当前计算进度为:9.9%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 19 个省市区地址为: 福建省泉州市晋江市 ,当前此区地址有: 4 ,当前计算进度为:10.4%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 20 个省市区地址为: 上海市市辖区浦东新区 ,当前此区地址有: 6 ,当前计算进度为:11.0%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 21 个省市区地址为: 湖南省长沙市浏阳市 ,当前此区地址有: 6 ,当前计算进度为:11.5%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 22 个省市区地址为: 浙江省嘉兴市海宁市 ,当前此区地址有: 5 ,当前计算进度为:12.1%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 23 个省市区地址为: 山东省青岛市城阳区 ,当前此区地址有: 2 ,当前计算进度为:12.6%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 24 个省市区地址为: 广东省广州市海珠区 ,当前此区地址有: 2 ,当前计算进度为:13.2%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 25 个省市区地址为: 上海市市辖区青浦区 ,当前此区地址有: 8 ,当前计算进度为:13.7%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 26 个省市区地址为: 浙江省嘉兴市海盐县 ,当前此区地址有: 2 ,当前计算进度为:14.3%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 27 个省市区地址为: 浙江省绍兴市嵊州市 ,当前此区地址有: 2 ,当前计算进度为:14.8%
# Time: Wed Apr  6 15:49:45 2022
# -----------------------------------------------------------------------
# 循环第 28 个省市区地址为: 广东省深圳市龙岗区 ,当前此区地址有: 16 ,当前计算进度为:15.4%
# Time: Wed Apr  6 15:49:46 2022
# -----------------------------------------------------------------------
# 循环第 29 个省市区地址为: 江苏省南京市雨花台区 ,当前此区地址有: 2 ,当前计算进度为:15.9%
# Time: Wed Apr  6 15:49:46 2022
# -----------------------------------------------------------------------
# 循环第 30 个省市区地址为: 江西省南昌市南昌县 ,当前此区地址有: 2 ,当前计算进度为:16.5%
# Time: Wed Apr  6 15:49:46 2022
# -----------------------------------------------------------------------
# 循环第 31 个省市区地址为: 北京市市辖区丰台区 ,当前此区地址有: 11 ,当前计算进度为:17.0%
# Time: Wed Apr  6 15:49:46 2022
# -----------------------------------------------------------------------
# 循环第 32 个省市区地址为: 山东省德州市德城区 ,当前此区地址有: 2 ,当前计算进度为:17.6%
# Time: Wed Apr  6 15:49:46 2022
# -----------------------------------------------------------------------
# 循环第 33 个省市区地址为: 浙江省杭州市萧山区 ,当前此区地址有: 4 ,当前计算进度为:18.1%
# Time: Wed Apr  6 15:49:46 2022
# -----------------------------------------------------------------------
# 循环第 34 个省市区地址为: 山东省烟台市莱山区 ,当前此区地址有: 2 ,当前计算进度为:18.7%
# Time: Wed Apr  6 15:49:46 2022
# -----------------------------------------------------------------------
# 循环第 35 个省市区地址为: 山东省青岛市崂山区 ,当前此区地址有: 4 ,当前计算进度为:19.2%
# Time: Wed Apr  6 15:49:46 2022
# -----------------------------------------------------------------------
# 循环第 36 个省市区地址为: 江苏省苏州市昆山市 ,当前此区地址有: 11 ,当前计算进度为:19.8%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 37 个省市区地址为: 山东省青岛市胶州市 ,当前此区地址有: 2 ,当前计算进度为:20.3%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 38 个省市区地址为: 辽宁省辽阳市宏伟区 ,当前此区地址有: 2 ,当前计算进度为:20.9%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 39 个省市区地址为: 辽宁省鞍山市立山区 ,当前此区地址有: 2 ,当前计算进度为:21.4%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 40 个省市区地址为: 浙江省绍兴市诸暨市 ,当前此区地址有: 9 ,当前计算进度为:22.0%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 41 个省市区地址为: 广东省佛山市三水区 ,当前此区地址有: 2 ,当前计算进度为:22.5%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 42 个省市区地址为: 湖北省武汉市江夏区 ,当前此区地址有: 3 ,当前计算进度为:23.1%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 43 个省市区地址为: 四川省成都市简阳市 ,当前此区地址有: 2 ,当前计算进度为:23.6%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 44 个省市区地址为: 广东省珠海市金湾区 ,当前此区地址有: 3 ,当前计算进度为:24.2%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 45 个省市区地址为: 山东省青岛市市北区 ,当前此区地址有: 2 ,当前计算进度为:24.7%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 46 个省市区地址为: 重庆市市辖区南岸区 ,当前此区地址有: 2 ,当前计算进度为:25.3%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 47 个省市区地址为: 浙江省宁波市宁海县 ,当前此区地址有: 3 ,当前计算进度为:25.8%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 48 个省市区地址为: 上海市市辖区闵行区 ,当前此区地址有: 11 ,当前计算进度为:26.4%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 49 个省市区地址为: 福建省厦门市翔安区 ,当前此区地址有: 2 ,当前计算进度为:26.9%
# Time: Wed Apr  6 15:49:47 2022
# -----------------------------------------------------------------------
# 循环第 50 个省市区地址为: 浙江省金华市永康市 ,当前此区地址有: 3 ,当前计算进度为:27.5%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 51 个省市区地址为: 山东省济宁市兖州区 ,当前此区地址有: 2 ,当前计算进度为:28.0%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 52 个省市区地址为: 浙江省台州市椒江区 ,当前此区地址有: 4 ,当前计算进度为:28.6%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 53 个省市区地址为: 辽宁省鞍山市铁东区 ,当前此区地址有: 2 ,当前计算进度为:29.1%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 54 个省市区地址为: 上海市市辖区奉贤区 ,当前此区地址有: 6 ,当前计算进度为:29.7%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 55 个省市区地址为: 广东省广州市黄埔区 ,当前此区地址有: 11 ,当前计算进度为:30.2%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 56 个省市区地址为: 四川省成都市武侯区 ,当前此区地址有: 6 ,当前计算进度为:30.8%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 57 个省市区地址为: 安徽省宣城市宁国市 ,当前此区地址有: 4 ,当前计算进度为:31.3%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 58 个省市区地址为: 浙江省杭州市拱墅区 ,当前此区地址有: 2 ,当前计算进度为:31.9%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 59 个省市区地址为: 浙江省杭州市桐庐县 ,当前此区地址有: 2 ,当前计算进度为:32.4%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 60 个省市区地址为: 广东省佛山市禅城区 ,当前此区地址有: 3 ,当前计算进度为:33.0%
# Time: Wed Apr  6 15:49:48 2022
# -----------------------------------------------------------------------
# 循环第 61 个省市区地址为: 浙江省宁波市江北区 ,当前此区地址有: 2 ,当前计算进度为:33.5%
# Time: Wed Apr  6 15:49:49 2022
# -----------------------------------------------------------------------
# 循环第 62 个省市区地址为: 江苏省苏州市张家港市 ,当前此区地址有: 16 ,当前计算进度为:34.1%
# Time: Wed Apr  6 15:49:49 2022
# -----------------------------------------------------------------------
# 循环第 63 个省市区地址为: 浙江省台州市温岭市 ,当前此区地址有: 5 ,当前计算进度为:34.6%
# Time: Wed Apr  6 15:49:49 2022
# -----------------------------------------------------------------------
# 循环第 64 个省市区地址为: 浙江省台州市仙居县 ,当前此区地址有: 2 ,当前计算进度为:35.2%
# Time: Wed Apr  6 15:49:49 2022
# -----------------------------------------------------------------------
# 循环第 65 个省市区地址为: 福建省厦门市海沧区 ,当前此区地址有: 5 ,当前计算进度为:35.7%
# Time: Wed Apr  6 15:49:49 2022
# -----------------------------------------------------------------------
# 循环第 66 个省市区地址为: 山东省枣庄市市中区 ,当前此区地址有: 2 ,当前计算进度为:36.3%
# Time: Wed Apr  6 15:49:49 2022
# -----------------------------------------------------------------------
# 循环第 67 个省市区地址为: 北京市市辖区朝阳区 ,当前此区地址有: 18 ,当前计算进度为:36.8%
# Time: Wed Apr  6 15:49:49 2022
# -----------------------------------------------------------------------
# 循环第 68 个省市区地址为: 江苏省常州市新北区 ,当前此区地址有: 4 ,当前计算进度为:37.4%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 69 个省市区地址为: 江苏省南通市如皋市 ,当前此区地址有: 3 ,当前计算进度为:37.9%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 70 个省市区地址为: 江苏省苏州市常熟市 ,当前此区地址有: 7 ,当前计算进度为:38.5%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 71 个省市区地址为: 浙江省嘉兴市嘉善县 ,当前此区地址有: 5 ,当前计算进度为:39.0%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 72 个省市区地址为: 安徽省合肥市蜀山区 ,当前此区地址有: 2 ,当前计算进度为:39.6%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 73 个省市区地址为: 浙江省温州市平阳县 ,当前此区地址有: 2 ,当前计算进度为:40.1%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 74 个省市区地址为: 上海市市辖区嘉定区 ,当前此区地址有: 4 ,当前计算进度为:40.7%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 75 个省市区地址为: 江苏省无锡市宜兴市 ,当前此区地址有: 5 ,当前计算进度为:41.2%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 76 个省市区地址为: 湖南省株洲市荷塘区 ,当前此区地址有: 2 ,当前计算进度为:41.8%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 77 个省市区地址为: 北京市市辖区东城区 ,当前此区地址有: 3 ,当前计算进度为:42.3%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 78 个省市区地址为: 浙江省金华市义乌市 ,当前此区地址有: 3 ,当前计算进度为:42.9%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 79 个省市区地址为: 江苏省南京市栖霞区 ,当前此区地址有: 2 ,当前计算进度为:43.4%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 80 个省市区地址为: 广东省汕头市龙湖区 ,当前此区地址有: 2 ,当前计算进度为:44.0%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 81 个省市区地址为: 浙江省宁波市余姚市 ,当前此区地址有: 2 ,当前计算进度为:44.5%
# Time: Wed Apr  6 15:49:50 2022
# -----------------------------------------------------------------------
# 循环第 82 个省市区地址为: 福建省厦门市思明区 ,当前此区地址有: 6 ,当前计算进度为:45.1%
# Time: Wed Apr  6 15:49:51 2022
# -----------------------------------------------------------------------
# 循环第 83 个省市区地址为: 北京市市辖区西城区 ,当前此区地址有: 5 ,当前计算进度为:45.6%
# Time: Wed Apr  6 15:49:51 2022
# -----------------------------------------------------------------------
# 循环第 84 个省市区地址为: 江苏省苏州市太仓市 ,当前此区地址有: 3 ,当前计算进度为:46.2%
# Time: Wed Apr  6 15:49:51 2022
# -----------------------------------------------------------------------
# 循环第 85 个省市区地址为: 广东省深圳市福田区 ,当前此区地址有: 29 ,当前计算进度为:46.7%
# Time: Wed Apr  6 15:49:51 2022
# -----------------------------------------------------------------------
# 循环第 86 个省市区地址为: 江苏省镇江市丹阳市 ,当前此区地址有: 2 ,当前计算进度为:47.3%
# Time: Wed Apr  6 15:49:51 2022
# -----------------------------------------------------------------------
# 循环第 87 个省市区地址为: 安徽省芜湖市鸠江区 ,当前此区地址有: 2 ,当前计算进度为:47.8%
# Time: Wed Apr  6 15:49:51 2022
# -----------------------------------------------------------------------
# 循环第 88 个省市区地址为: 上海市市辖区杨浦区 ,当前此区地址有: 2 ,当前计算进度为:48.4%
# Time: Wed Apr  6 15:49:51 2022
# -----------------------------------------------------------------------
# 循环第 89 个省市区地址为: 江苏省常州市武进区 ,当前此区地址有: 6 ,当前计算进度为:48.9%
# Time: Wed Apr  6 15:49:52 2022
# -----------------------------------------------------------------------
# 循环第 90 个省市区地址为: 山东省潍坊市诸城市 ,当前此区地址有: 3 ,当前计算进度为:49.5%
# Time: Wed Apr  6 15:49:52 2022
# -----------------------------------------------------------------------
# 循环第 91 个省市区地址为: 广东省汕头市澄海区 ,当前此区地址有: 7 ,当前计算进度为:50.0%
# Time: Wed Apr  6 15:49:52 2022
# -----------------------------------------------------------------------
# 循环第 92 个省市区地址为: 浙江省温州市乐清市 ,当前此区地址有: 5 ,当前计算进度为:50.5%
# Time: Wed Apr  6 15:49:52 2022
# -----------------------------------------------------------------------
# 循环第 93 个省市区地址为: 江苏省宿迁市宿豫区 ,当前此区地址有: 2 ,当前计算进度为:51.1%
# Time: Wed Apr  6 15:49:52 2022
# -----------------------------------------------------------------------
# 循环第 94 个省市区地址为: 江苏省南通市通州区 ,当前此区地址有: 3 ,当前计算进度为:51.6%
# Time: Wed Apr  6 15:49:52 2022
# -----------------------------------------------------------------------
# 循环第 95 个省市区地址为: 山东省烟台市牟平区 ,当前此区地址有: 2 ,当前计算进度为:52.2%
# Time: Wed Apr  6 15:49:52 2022
# -----------------------------------------------------------------------
# 循环第 96 个省市区地址为: 北京市市辖区昌平区 ,当前此区地址有: 9 ,当前计算进度为:52.7%
# Time: Wed Apr  6 15:49:52 2022
# -----------------------------------------------------------------------
# 循环第 97 个省市区地址为: 浙江省杭州市余杭区 ,当前此区地址有: 11 ,当前计算进度为:53.3%
# Time: Wed Apr  6 15:49:52 2022
# -----------------------------------------------------------------------
# 循环第 98 个省市区地址为: 山东省烟台市芝罘区 ,当前此区地址有: 2 ,当前计算进度为:53.8%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 99 个省市区地址为: 广东省广州市白云区 ,当前此区地址有: 3 ,当前计算进度为:54.4%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 100 个省市区地址为: 上海市市辖区金山区 ,当前此区地址有: 7 ,当前计算进度为:54.9%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 101 个省市区地址为: 广东省广州市越秀区 ,当前此区地址有: 3 ,当前计算进度为:55.5%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 102 个省市区地址为: 辽宁省大连市中山区 ,当前此区地址有: 2 ,当前计算进度为:56.0%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 103 个省市区地址为: 海南省海口市秀英区 ,当前此区地址有: 2 ,当前计算进度为:56.6%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 104 个省市区地址为: 江苏省无锡市新吴区 ,当前此区地址有: 4 ,当前计算进度为:57.1%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 105 个省市区地址为: 山东省德州市禹城市 ,当前此区地址有: 3 ,当前计算进度为:57.7%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 106 个省市区地址为: 湖南省长沙市芙蓉区 ,当前此区地址有: 2 ,当前计算进度为:58.2%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 107 个省市区地址为: 广东省佛山市南海区 ,当前此区地址有: 11 ,当前计算进度为:58.8%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 108 个省市区地址为: 江苏省徐州市新沂市 ,当前此区地址有: 3 ,当前计算进度为:59.3%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 109 个省市区地址为: 福建省厦门市集美区 ,当前此区地址有: 2 ,当前计算进度为:59.9%
# Time: Wed Apr  6 15:49:53 2022
# -----------------------------------------------------------------------
# 循环第 110 个省市区地址为: 浙江省绍兴市上虞区 ,当前此区地址有: 4 ,当前计算进度为:60.4%
# Time: Wed Apr  6 15:49:54 2022
# -----------------------------------------------------------------------
# 循环第 111 个省市区地址为: 上海市市辖区徐汇区 ,当前此区地址有: 4 ,当前计算进度为:61.0%
# Time: Wed Apr  6 15:49:54 2022
# -----------------------------------------------------------------------
# 循环第 112 个省市区地址为: 河南省焦作市中站区 ,当前此区地址有: 2 ,当前计算进度为:61.5%
# Time: Wed Apr  6 15:49:54 2022
# -----------------------------------------------------------------------
# 循环第 113 个省市区地址为: 新疆维吾尔自治区乌鲁木齐市新市区 ,当前此区地址有: 2 ,当前计算进度为:62.1%
# Time: Wed Apr  6 15:49:54 2022
# -----------------------------------------------------------------------
# 循环第 114 个省市区地址为: 江苏省无锡市惠山区 ,当前此区地址有: 2 ,当前计算进度为:62.6%
# Time: Wed Apr  6 15:49:54 2022
# -----------------------------------------------------------------------
# 循环第 115 个省市区地址为: 山东省潍坊市寿光市 ,当前此区地址有: 2 ,当前计算进度为:63.2%
# Time: Wed Apr  6 15:49:54 2022
# -----------------------------------------------------------------------
# 循环第 116 个省市区地址为: 广东省深圳市南山区 ,当前此区地址有: 84 ,当前计算进度为:63.7%
# Time: Wed Apr  6 15:49:56 2022
# -----------------------------------------------------------------------
# 循环第 117 个省市区地址为: 浙江省温州市永嘉县 ,当前此区地址有: 2 ,当前计算进度为:64.3%
# Time: Wed Apr  6 15:49:56 2022
# -----------------------------------------------------------------------
# 循环第 118 个省市区地址为: 北京市市辖区石景山区 ,当前此区地址有: 6 ,当前计算进度为:64.8%
# Time: Wed Apr  6 15:49:56 2022
# -----------------------------------------------------------------------
# 循环第 119 个省市区地址为: 福建省福州市闽侯县 ,当前此区地址有: 3 ,当前计算进度为:65.4%
# Time: Wed Apr  6 15:49:56 2022
# -----------------------------------------------------------------------
# 循环第 120 个省市区地址为: 上海市市辖区普陀区 ,当前此区地址有: 2 ,当前计算进度为:65.9%
# Time: Wed Apr  6 15:49:56 2022
# -----------------------------------------------------------------------
# 循环第 121 个省市区地址为: 北京市市辖区顺义区 ,当前此区地址有: 3 ,当前计算进度为:66.5%
# Time: Wed Apr  6 15:49:56 2022
# -----------------------------------------------------------------------
# 循环第 122 个省市区地址为: 浙江省金华市东阳市 ,当前此区地址有: 3 ,当前计算进度为:67.0%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 123 个省市区地址为: 北京市市辖区大兴区 ,当前此区地址有: 4 ,当前计算进度为:67.6%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 124 个省市区地址为: 四川省眉山市青神县 ,当前此区地址有: 2 ,当前计算进度为:68.1%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 125 个省市区地址为: 湖南省长沙市岳麓区 ,当前此区地址有: 4 ,当前计算进度为:68.7%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 126 个省市区地址为: 上海市市辖区长宁区 ,当前此区地址有: 3 ,当前计算进度为:69.2%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 127 个省市区地址为: 江苏省苏州市吴中区 ,当前此区地址有: 4 ,当前计算进度为:69.8%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 128 个省市区地址为: 浙江省宁波市北仑区 ,当前此区地址有: 2 ,当前计算进度为:70.3%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 129 个省市区地址为: 山东省烟台市莱阳市 ,当前此区地址有: 2 ,当前计算进度为:70.9%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 130 个省市区地址为: 山东省潍坊市高密市 ,当前此区地址有: 2 ,当前计算进度为:71.4%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 131 个省市区地址为: 浙江省绍兴市新昌县 ,当前此区地址有: 6 ,当前计算进度为:72.0%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 132 个省市区地址为: 湖北省武汉市洪山区 ,当前此区地址有: 3 ,当前计算进度为:72.5%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 133 个省市区地址为: 江苏省南京市建邺区 ,当前此区地址有: 3 ,当前计算进度为:73.1%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 134 个省市区地址为: 江苏省南通市海门市 ,当前此区地址有: 2 ,当前计算进度为:73.6%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 135 个省市区地址为: 广东省珠海市香洲区 ,当前此区地址有: 3 ,当前计算进度为:74.2%
# Time: Wed Apr  6 15:49:57 2022
# -----------------------------------------------------------------------
# 循环第 136 个省市区地址为: 广东省佛山市顺德区 ,当前此区地址有: 9 ,当前计算进度为:74.7%
# Time: Wed Apr  6 15:49:58 2022
# -----------------------------------------------------------------------
# 循环第 137 个省市区地址为: 浙江省杭州市西湖区 ,当前此区地址有: 6 ,当前计算进度为:75.3%
# Time: Wed Apr  6 15:49:58 2022
# -----------------------------------------------------------------------
# 循环第 138 个省市区地址为: 北京市市辖区海淀区 ,当前此区地址有: 86 ,当前计算进度为:75.8%
# Time: Wed Apr  6 15:50:00 2022
# -----------------------------------------------------------------------
# 循环第 139 个省市区地址为: 山东省潍坊市昌乐县 ,当前此区地址有: 2 ,当前计算进度为:76.4%
# Time: Wed Apr  6 15:50:00 2022
# -----------------------------------------------------------------------
# 循环第 140 个省市区地址为: 广东省深圳市罗湖区 ,当前此区地址有: 11 ,当前计算进度为:76.9%
# Time: Wed Apr  6 15:50:00 2022
# -----------------------------------------------------------------------
# 循环第 141 个省市区地址为: 福建省福州市马尾区 ,当前此区地址有: 3 ,当前计算进度为:77.5%
# Time: Wed Apr  6 15:50:00 2022
# -----------------------------------------------------------------------
# 循环第 142 个省市区地址为: 山东省烟台市莱州市 ,当前此区地址有: 2 ,当前计算进度为:78.0%
# Time: Wed Apr  6 15:50:00 2022
# -----------------------------------------------------------------------
# 循环第 143 个省市区地址为: 浙江省杭州市滨江区 ,当前此区地址有: 19 ,当前计算进度为:78.6%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 144 个省市区地址为: 浙江省湖州市德清县 ,当前此区地址有: 4 ,当前计算进度为:79.1%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 145 个省市区地址为: 广东省广州市花都区 ,当前此区地址有: 2 ,当前计算进度为:79.7%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 146 个省市区地址为: 广东省广州市南沙区 ,当前此区地址有: 2 ,当前计算进度为:80.2%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 147 个省市区地址为: 浙江省宁波市鄞州区 ,当前此区地址有: 5 ,当前计算进度为:80.8%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 148 个省市区地址为: 山东省青岛市即墨市 ,当前此区地址有: 4 ,当前计算进度为:81.3%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 149 个省市区地址为: 江苏省南京市浦口区 ,当前此区地址有: 2 ,当前计算进度为:81.9%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 150 个省市区地址为: 山东省东营市东营区 ,当前此区地址有: 2 ,当前计算进度为:82.4%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 151 个省市区地址为: 浙江省杭州市临安市 ,当前此区地址有: 6 ,当前计算进度为:83.0%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 152 个省市区地址为: 湖北省武汉市江岸区 ,当前此区地址有: 2 ,当前计算进度为:83.5%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 153 个省市区地址为: 四川省成都市锦江区 ,当前此区地址有: 3 ,当前计算进度为:84.1%
# Time: Wed Apr  6 15:50:01 2022
# -----------------------------------------------------------------------
# 循环第 154 个省市区地址为: 上海市市辖区静安区 ,当前此区地址有: 2 ,当前计算进度为:84.6%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 155 个省市区地址为: 福建省厦门市湖里区 ,当前此区地址有: 2 ,当前计算进度为:85.2%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 156 个省市区地址为: 江苏省南通市启东市 ,当前此区地址有: 2 ,当前计算进度为:85.7%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 157 个省市区地址为: 江苏省南京市江宁区 ,当前此区地址有: 5 ,当前计算进度为:86.3%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 158 个省市区地址为: 广东省汕头市濠江区 ,当前此区地址有: 2 ,当前计算进度为:86.8%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 159 个省市区地址为: 广东省揭阳市普宁市 ,当前此区地址有: 3 ,当前计算进度为:87.4%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 160 个省市区地址为: 福建省泉州市南安市 ,当前此区地址有: 2 ,当前计算进度为:87.9%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 161 个省市区地址为: 浙江省宁波市海曙区 ,当前此区地址有: 2 ,当前计算进度为:88.5%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 162 个省市区地址为: 河南省省直辖县级行政区划济源市 ,当前此区地址有: 2 ,当前计算进度为:89.0%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 163 个省市区地址为: 山东省淄博市临淄区 ,当前此区地址有: 4 ,当前计算进度为:89.6%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 164 个省市区地址为: 广东省广州市增城区 ,当前此区地址有: 3 ,当前计算进度为:90.1%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 165 个省市区地址为: 福建省福州市仓山区 ,当前此区地址有: 4 ,当前计算进度为:90.7%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 166 个省市区地址为: 湖南省长沙市宁乡县 ,当前此区地址有: 2 ,当前计算进度为:91.2%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 167 个省市区地址为: 浙江省杭州市富阳区 ,当前此区地址有: 2 ,当前计算进度为:91.8%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 168 个省市区地址为: 山东省临沂市临沭县 ,当前此区地址有: 2 ,当前计算进度为:92.3%
# Time: Wed Apr  6 15:50:02 2022
# -----------------------------------------------------------------------
# 循环第 169 个省市区地址为: 江苏省苏州市吴江区 ,当前此区地址有: 8 ,当前计算进度为:92.9%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 170 个省市区地址为: 江苏省苏州市相城区 ,当前此区地址有: 3 ,当前计算进度为:93.4%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 171 个省市区地址为: 新疆维吾尔自治区昌吉回族自治州昌吉市 ,当前此区地址有: 2 ,当前计算进度为:94.0%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 172 个省市区地址为: 山东省淄博市沂源县 ,当前此区地址有: 2 ,当前计算进度为:94.5%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 173 个省市区地址为: 北京市市辖区房山区 ,当前此区地址有: 3 ,当前计算进度为:95.1%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 174 个省市区地址为: 江西省景德镇市昌江区 ,当前此区地址有: 2 ,当前计算进度为:95.6%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 175 个省市区地址为: 四川省成都市青羊区 ,当前此区地址有: 2 ,当前计算进度为:96.2%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 176 个省市区地址为: 浙江省杭州市江干区 ,当前此区地址有: 3 ,当前计算进度为:96.7%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 177 个省市区地址为: 山东省烟台市龙口市 ,当前此区地址有: 5 ,当前计算进度为:97.3%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 178 个省市区地址为: 浙江省台州市玉环县 ,当前此区地址有: 2 ,当前计算进度为:97.8%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 179 个省市区地址为: 广东省广州市番禺区 ,当前此区地址有: 8 ,当前计算进度为:98.4%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 180 个省市区地址为: 山东省淄博市张店区 ,当前此区地址有: 2 ,当前计算进度为:98.9%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# 循环第 181 个省市区地址为: 湖南省郴州市苏仙区 ,当前此区地址有: 2 ,当前计算进度为:99.5%
# Time: Wed Apr  6 15:50:03 2022
# -----------------------------------------------------------------------
# Time used: 21.54505181312561 s

# %%
collect_data_1
# Out:
#       目标地址省市区  目标地址代码                      目标地址   被比较地址省市区 被比较地址代码  \
# 2   浙江省绍兴市诸暨市  002203                    店口镇工业区  浙江省绍兴市诸暨市  002590
# 1   安徽省宣城市宁国市  300475            经济技术开发区创业北路16号  安徽省宣城市宁国市  002538
# 6   广东省广州市天河区  300805   黄埔大道西平云路163号通讯大楼4层东部之三房  广东省广州市天河区  002967
# 46  广东省深圳市南山区  300572    粤海街道学府路63号高新区联合总部大厦35楼  广东省深圳市南山区  002587
# 49  广东省深圳市南山区  300531    粤海街道学府路63号高新区联合总部大厦36楼  广东省深圳市南山区  002587
# ..        ...     ...                       ...        ...     ...
# 34  广东省深圳市南山区  300771       学苑大道1001号南山智园C3栋15层  广东省深圳市南山区  002660
# 33  广东省深圳市南山区  300771       学苑大道1001号南山智园C3栋15层  广东省深圳市南山区  002618
# 10  广东省深圳市南山区  300771       学苑大道1001号南山智园C3栋15层  广东省深圳市南山区  002197
# 5   广东省深圳市南山区  300771       学苑大道1001号南山智园C3栋15层  广东省深圳市南山区  002139
# 0   湖南省郴州市苏仙区  002716  白露塘镇福城大道1号（湖南郴州高新技术产业园内）  湖南省郴州市苏仙区  002848
#
#                      被比较地址       相似度  adcode
# 2                   店口镇工业区  1.000000  330681
# 1                  经济技术开发区  1.000000  341881
# 6             黄埔大道西平云路163号  0.961010  440106
# 46  粤海街道学府路63号高新区联合总部大厦10楼  0.945883  440305
# 49  粤海街道学府路63号高新区联合总部大厦10楼  0.935560  440305
# ..                     ...       ...     ...
# 34           松白路关外小白芒桑泰工业园  0.000000  440305
# 33           高新园朗山一路丹邦科技大楼  0.000000  440305
# 10            粤海街道西海岸大厦18楼  0.000000  440305
# 5     高新技术产业园清华大学研究院B区413房  0.000000  440305
# 0             观山洞街道高斯贝尔产业园  0.000000  431003
#
# [10046 rows x 8 columns]

# %%
collect_data_1.to_csv('相似度排行表.csv')

# %%
#高相似度筛选之后进行地图可视化
collect_data = collect_data_1[collect_data_1["相似度"]>=0.8].sort_values(by=["相似度"], ascending=[False])
drawer.draw_locations(collect_data [cpca._ADCODE], "processed1.html")

# %%
df
# Out:
#         公司代码  公司简称                                        注册地址
# 0     300001   特锐德                            山东省青岛市崂山区松岭路336号
# 1     300002  神州泰岳                 北京市海淀区万泉庄路28号万柳新贵大厦A座6层601室
# 2     300003  乐普医疗                                北京市昌平区超前路37号
# 3     300004  南风股份                     广东省佛山市南海区小塘三环西路(狮南段)31号
# 4     300005   探路者                         北京市昌平区科技园区永安路26号609
# ...      ...   ...                                         ...
# 1768  002986  宇新股份         湖南省长沙市雨花区迎新路868号德思勤城市广场第A-2地块第7栋16层
# 1769  002987   京北方                            北京市海淀区西三环北路25号7层
# 1770  002988  豪美新材                        广东省清远市高新技术产业开发区泰基工业城
# 1771  002990  盛视科技  广东省深圳市福田区沙头街道天安社区泰然十路天安创新科技广场二期东座1601、1605
# 1772  003816  中国广核                广东省深圳市福田区深南大道2002号中广核大厦南楼18楼
#
# [1773 rows x 3 columns]

# %%
#节点表
df1 = pd.read_excel("创业板.xlsx", dtype={'公司代码': 'str'})
df2 = pd.read_excel("中小企业板.xlsx", dtype={'公司代码': 'str'})
df = pd.concat([df1,df2],axis=0,ignore_index=True)
#这里是给节点分配属性的过程，在信贷中则为客户的其他征信标签信息
df_node = df[['公司代码', '公司简称', '公司全称', '注册地址', '所属行业']]
df_node = df_node.rename(columns = {"公司代码": ":ID"})
df_node.to_csv("node.csv", index =False)

# %%
#边关系表
df_rela = collect_data[["目标地址代码", "被比较地址代码", "相似度"]]
df_relation = df_rela.rename(columns = {"目标地址代码": ":START_ID", "被比较地址代码": ":END_ID", "相似度":":TYPE"})
df_relation.to_csv("relationship.csv", index = False)
